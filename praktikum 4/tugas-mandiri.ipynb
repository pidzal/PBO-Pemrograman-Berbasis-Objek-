# %%
# Parent Class
class Kendaraan:
    def __init__(self, merk, tahun_produksi, warna):
        self.__merk = merk
        self.__tahun_produksi = tahun_produksi
        self.__warna = warna

    def tampilkan_info(self):
        print(f"Merk          : {self.__merk}")
        print(f"Tahun Produksi: {self.__tahun_produksi}")
        print(f"Warna         : {self.__warna}")

    def nyalakan_mesin(self):
        print("Mesin kendaraan menyala.")


# Child Class Mobil
class Mobil(Kendaraan):
    def __init__(self, merk, tahun_produksi, warna, jumlah_pintu):
        super().__init__(merk, tahun_produksi, warna)
        self.__jumlah_pintu = jumlah_pintu

    # Override method tampilkan_info
    def tampilkan_info(self):
        super().tampilkan_info()
        print(f"Jumlah Pintu  : {self.__jumlah_pintu}")

    # Method spesifik mobil
    def buka_pintu_bagasi(self):
        print("Pintu bagasi terbuka.")


# Child Class Motor
class Motor(Kendaraan):
    def __init__(self, merk, tahun_produksi, warna, kapasitas_tangki):
        super().__init__(merk, tahun_produksi, warna)
        self.__kapasitas_tangki = kapasitas_tangki

    # Override method nyalakan_mesin
    def nyalakan_mesin(self):
        print("Brmm... Mesin motor dinyalakan dengan kick starter!")

    # Method tambahan spesifik motor
    def isi_bensin(self):
        print(f"Mengisi bensin hingga {self.__kapasitas_tangki} liter.")
        

# --- Bagian utama program ---
mobil1 = Mobil("Toyota Avanza", 2020, "Hitam", 4)
motor1 = Motor("Honda Beat", 2022, "Merah", 5)

print("\n=== Info Mobil ===")
mobil1.tampilkan_info()
mobil1.nyalakan_mesin()
mobil1.buka_pintu_bagasi()

print("\n=== Info Motor ===")
motor1.tampilkan_info()
motor1.nyalakan_mesin()
motor1.isi_bensin()
# Out:
# === Info Mobil ===
# Merk          : Toyota Avanza
# Tahun Produksi: 2020
# Warna         : Hitam
# Jumlah Pintu  : 4
# Mesin kendaraan menyala.
# Pintu bagasi terbuka.
#
# === Info Motor ===
# Merk          : Honda Beat
# Tahun Produksi: 2022
# Warna         : Merah
# Brmm... Mesin motor dinyalakan dengan kick starter!
# Mengisi bensin hingga 5 liter.
