# %%
import math

# mengitung akar kuadrat
angka = 16
akar = math.sqrt(angka)
print(f"akar kuadrat dari {angka} adalah {akar}")
# Out:
# akar kuadrat dari 16 adalah 4.0

# %%
# menghitung pangkat 
hasil = math.pow(2, 3)
print(F"2 pangkat 3 adalah {hasil}")
# Out:
# 2 pangkat 3 adalah 8.0
