# %%
import datetime

# mendapatkan waktu sekarang
waktu_sekarang = datetime.datetime.now()
print(f"waktu sekarang adalah {waktu_sekarang}")
# Out:
# waktu sekarang adalah 2025-10-14 13:58:40.764609

# %%
# menggunakan timedelta untuk menghitung selisih waktu

hari_ini = datetime.datetime.now()
satu_hari = datetime.timedelta(days=1)
besok = hari_ini + satu_hari
print(f"hari ini adalah {hari_ini}")
print(f"besok adalah {besok}")
# Out:
# hari ini adalah 2025-10-14 11:52:56.347173
# besok adalah 2025-10-15 11:52:56.347173
